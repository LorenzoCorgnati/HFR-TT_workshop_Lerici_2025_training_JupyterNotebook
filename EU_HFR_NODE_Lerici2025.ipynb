# %% [markdown]
# ![header](header.jpg)

# %% [markdown]
# # HANDS ON SESSION FOR HIGH FREQUENCY RADAR DATA PROCESSING

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Run" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# # Table of Contents
# * [1. Introduction](#chapter1)
# * [2. Setup](#chapter2)
#     * [2.1. Python packages](#section_2_1)
#     * [2.2. HFR network and station information](#section_2_2)
#     * [2.3. HFR network specification](#section_2_3)
# * [3. Inspect total current field dataset](#chapter3)
#     * [3.1. Set up a cluster for enabling parallelized access to data](#section_3_1)
#     * [3.2. Open dataset from the EU HFR NODE THREDDS Data Server](#section_3_2)
#     * [3.3. Select the variable to be inspected](#section_3_3)
#     * [3.4. Inspect the entire spatial domain for a variable at a specific time step](#section_3_4)
#     * [3.5. Inspect the time series for a variable at a specific location for a specified time range.](#section_3_5)
#     * [3.6. Compute the average of a variable over the entire spatial domain for a specified time period.](#section_3_6)
# * [4. Inspect radial current field datasets](#chapter4)
#     * [4.1. Open dataset from the EU HFR NODE THREDDS Data Server](#section_4_1)
#     * [4.2. Select the variable to be inspected](#section_4_2)
#     * [4.3. Inspect the entire spatial domain for a variable at a specific time step](#section_4_3)
#     * [4.4. Inspect the time series for a variable at a specific location for a specified time range.](#section_4_4)
#     * [4.5. Compute the average of a variable over the entire spatial domain for a specified time period.](#section_4_5)
#     * [4.6. Stop the cluster.](#section_4_6)

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction <a class="anchor" id="chapter1"></a>
# [Go back to the "Table of Contents"](#Table-of-Contents)
#
# This notebook focuses on providing basic routines for inspecting the HFR-derived surface current dataset produced by the operational Near Real Time (NRT) workflow of the [European HFR Node](https://www.hfrnode.eu/). The inspection is useful for assessing the datasets and modify the processing and QC parameters, if needed.
# The operational routines of the European HFR Node are available on the GitHub repository [https://github.com/LorenzoCorgnati/EU_HFR_NODE_pyHFR](https://github.com/LorenzoCorgnati/EU_HFR_NODE_pyHFR).
#
# The datasets used by this notebook are directly read from the [THREDDS Data Server](https://thredds.hfrnode.eu) of the European HFR Node.
#
# The comprehensive information about HFR networks and stations are read from the operational database of the European HFR Node. In order to insert or modify the information stored in the database, please use the online [webform](https://webform.hfrnode.eu) of the European HFR Node.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you have credentials yet to access the online webform of the European HFR Node?** <br>Please go [here](https://webform.hfrnode.eu) to set or recover them.
# </div>

# %% [markdown]
# ## 2. Setup <a class="anchor" id="chapter2"></a>
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# ### 2.1. Python packages <a id="section_2_1"></a>

# %% [markdown]
# For the notebook to properly run we need to first load the next packages available from the Jupyter Notebook Ecosystem. Please run the `next cell`:

# %%
import os
import fsspec
import xarray as xr
import hvplot.xarray
import intake
import cf_xarray
import numpy as np
import panel as pn
from matplotlib import path
import xoak
import pandas as pd
import panel as pn
import math

import warnings
warnings.filterwarnings("ignore")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9e8551c8-f6d1-4896-a1c3-c2c1997d13c0'>
#   <div id="cd8cc3e4-2cd7-46ee-88cd-adc74b6397be" data-root-id="9e8551c8-f6d1-4896-a1c3-c2c1997d13c0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6fc00795-7cd9-4da6-9940-a924590c6640":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"9e8551c8-f6d1-4896-a1c3-c2c1997d13c0"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"a93ba0da-cf66-4d85-b4d8-26cb7466af33","attributes":{"plot_id":"9e8551c8-f6d1-4896-a1c3-c2c1997d13c0","comm_id":"bbc9634989bf4345a6f90a32516b3af0","client_comm_id":"f3653b165aac4f72a46b1c4176801bc5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"6fc00795-7cd9-4da6-9940-a924590c6640","roots":{"9e8551c8-f6d1-4896-a1c3-c2c1997d13c0":"cd8cc3e4-2cd7-46ee-88cd-adc74b6397be"},"root_ids":["9e8551c8-f6d1-4896-a1c3-c2c1997d13c0"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ### 2.2. HFR network and station information <a id="section_2_2"></a>

# %% [markdown]
# Now we need to load information and metadata about the HFR networks and their radial stations. Please run the `next cell`:

# %%
# Load network information into a dataframe
allNetworkData = pd.read_csv('allNetworkData.csv')
    
# Load station information into a dataframe
allStationData = pd.read_csv('allStationData.csv')

# %% [markdown]
# ### 2.3. HFR network specification <a id="section_2_3"></a>

# %% [markdown]
# Now we need to specify the HFR network whose data are about to be inspected. Please specify the ID of the HFR network you manage and run the `next cell`:

# %%
networkID = 'HFR-TirLig' # REPLACE THIS NETWORK WITH THE ID OF THE NETWORK YOU MANAGE

# %% [markdown]
# Now we load information and metadata about the specified HFR network and its stations. Please run the `next cell`:

# %%
# Network
networkData = allNetworkData.loc[allNetworkData['network_id'] == networkID]

# Stations
stationData = allStationData.loc[allStationData['network_id'] == networkID]

# %% [markdown]
# And now we display them. Please run the `next cells`:

# %%
# Network
networkData
# Out:
#     network_id operational_from operational_to EDIOS_Series_id  EDMO_code  \
# 37  HFR-TirLig       2016-06-22            NaN      HFR-TirLig        134
#
#                                         metadata_page  \
# 37  https://thredds.hfrnode.eu:8443/thredds/NRTcur...
#
#                                                 title  \
# 37  Near Real Time Surface Ocean Velocity by HFR-T...
#
#                                               summary  \
# 37  The data set consists of maps of total velocit...
#
#                                      institution_name  \
# 37  National Research Council - Institute of Marin...
#
#                                    citation_statement  ...  \
# 37  Data collected and processed by CNR-ISMAR with...  ...
#
#    EU_HFR_processing_flag connected_to_NRT  connected_to_REP  \
# 37                      1              1.0               1.0
#
#     total_input_folder_path  \
# 37                      NaN
#
#                           total_HFRnetCDF_folder_path  \
# 37  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Tota...
#
#                                 total_mat_folder_path  TDS_root_url  \
# 37  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Tota...           NaN
#
#    SDC_distribution_flag                               SDC_OpenDAP_data_url  \
# 37                     1  https://thredds.hfrnode.eu:8443/thredds/dodsC/...
#
#                                       SDC_folder_path
# 37  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/SDC/...
#
# [1 rows x 44 columns]

# %%
# Stations
stationData
# Out:
#     station_id  network_id   station_full_name  site_lon  site_lat  \
# 119       LIGW  HFR-TirLig        Celle Ligure   8.56408   44.3465
# 144       MONT  HFR-TirLig  Monterosso al Mare   9.65333   44.1458
# 165       PCOR  HFR-TirLig        Punta Corone   9.65930   44.1435
# 169       PFIN  HFR-TirLig           Portofino   9.21836   44.2987
# 253       TINO  HFR-TirLig      Isola del Tino   9.84922   44.0264
# 266       VIAR  HFR-TirLig           Viareggio  10.23730   43.8579
#
#     operational_from operational_to  permanent_installation  oceanops_ref  \
# 119       2021-12-17            NaN                       1     6103569.0
# 144       2016-06-22     2018-03-26                       0     6103578.0
# 165       2018-04-04            NaN                       1     6103575.0
# 169       2020-07-17            NaN                       1     6103570.0
# 253       2016-08-04            NaN                       1     6103576.0
# 266       2018-09-13            NaN                       1     6103571.0
#
#       wmo_code  ... radial_QC_radial_count_threshold  number_of_range_cells  \
# 119  6103569.0  ...                              200                     67
# 144  6103578.0  ...                              200                     51
# 165  6103575.0  ...                              200                     51
# 169  6103570.0  ...                              200                     67
# 253  6103576.0  ...                              200                     51
# 266  6103571.0  ...                              200                     51
#
#     EU_HFR_processing_flag connected_to_NRT connected_to_REP  \
# 119                      1                1                1
# 144                      1                0                1
# 165                      1                1                1
# 169                      1                1                1
# 253                      1                1                1
# 266                      1                1                1
#
#                               radial_input_folder_path  \
# 119  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...
# 144  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...
# 165  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...
# 169  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...
# 253  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...
# 266  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...
#
#                           radial_HFRnetCDF_folder_path SDC_distribution_flag  \
# 119  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...                     1
# 144  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...                     1
# 165  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...                     1
# 169  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...                     1
# 253  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...                     1
# 266  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/Radi...                     1
#
#                                   SDC_OpenDAP_data_url  \
# 119  https://thredds.hfrnode.eu:8443/thredds/dodsC/...
# 144  https://thredds.hfrnode.eu:8443/thredds/dodsC/...
# 165  https://thredds.hfrnode.eu:8443/thredds/dodsC/...
# 169  https://thredds.hfrnode.eu:8443/thredds/dodsC/...
# 253  https://thredds.hfrnode.eu:8443/thredds/dodsC/...
# 266  https://thredds.hfrnode.eu:8443/thredds/dodsC/...
#
#                                        SDC_folder_path
# 119  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/SDC/...
# 144  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/SDC/...
# 165  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/SDC/...
# 169  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/SDC/...
# 253  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/SDC/...
# 266  /home/radarcombine/EU_HFR_NODE/HFR-TirLig/SDC/...
#
# [6 rows x 42 columns]

# %% [markdown]
# ## 3. Inspect total current field dataset<a class="anchor" id="chapter3"></a>
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# In this section we'll inspect the total velocity field data produced by your HFR network. In particular, we'll check: **(i) the entire spatial domain for a variable at a specific time step, (ii) the time series of a variable at a specific location for a specified time range, (iii) the average of a variable over the entire spatial domain for a specified time period**.

# %% [markdown]
# ### 3.1. Set up a cluster for enabling parallelized access to data<a id="section_3_1"></a>

# %% [markdown]
# We'll open the datasets for taking advantage of parallel compute environments using `dask`. We're going to start a **cluster** now so that future steps can take advantage of this ability.
#
# This is an optional step, but speeds up data loading and processing significantly, especially when accessing data from the cloud. Please run the `next cell`:

# %%
from dask.distributed import LocalCluster, Client
cluster = LocalCluster()
client = Client(cluster)

client
# Out:
# <Client: 'tcp://127.0.0.1:40185' processes=8 threads=32, memory=62.48 GiB>

# %% [markdown]
# ### 3.2. Open dataset from the EU HFR NODE THREDDS Data Server<a id="section_3_2"></a>

# %% [markdown]
# This operation could take a while because it reads the whole aggregated dataset stored on the EU HFR NODE THREDDS Data Server. Please run the `next cell`:

# %%
# Get the TDS URL of the dataset
OpenDAPdataUrl = networkData.at[networkData.index.values.astype(int)[0],'SDC_OpenDAP_data_url']

# Read aggregated total dataset from THREDDS catalog via OpenDAP
ds = xr.open_dataset(OpenDAPdataUrl, decode_times=True, chunks={})
ds
# Out:
# <xarray.Dataset> Size: 47GB
# Dimensions:           (DEPTH: 1, LATITUDE: 70, LONGITUDE: 121, TIME: 74717,
#                        MAXSITE: 150, MAXINST: 50, REFMAX: 1)
# Coordinates:
#   * DEPTH             (DEPTH) float32 4B 0.0
#   * LATITUDE          (LATITUDE) float32 280B 43.25 43.27 43.29 ... 44.48 44.5
#   * LONGITUDE         (LONGITUDE) float32 484B 7.507 7.532 7.557 ... 10.47 10.49
#   * TIME              (TIME) datetime64[ns] 598kB 2016-08-04T08:00:00 ... 202...
# Dimensions without coordinates: MAXSITE, MAXINST, REFMAX
# Data variables: (12/29)
#     crs               int16 2B ...
#     NARX              (TIME, MAXSITE) float32 45MB dask.array<chunksize=(74717, 150), meta=np.ndarray>
#     NATX              (TIME, MAXSITE) float32 45MB dask.array<chunksize=(74717, 150), meta=np.ndarray>
#     SLTR              (TIME, MAXSITE) float64 90MB dask.array<chunksize=(74717, 150), meta=np.ndarray>
#     SLNR              (TIME, MAXSITE) float64 90MB dask.array<chunksize=(74717, 150), meta=np.ndarray>
#     SLTT              (TIME, MAXSITE) float64 90MB dask.array<chunksize=(74717, 150), meta=np.ndarray>
#     ...                ...
#     EWCT              (TIME, DEPTH, LATITUDE, LONGITUDE) float64 5GB dask.array<chunksize=(74717, 1, 70, 121), meta=np.ndarray>
#     NSCT              (TIME, DEPTH, LATITUDE, LONGITUDE) float64 5GB dask.array<chunksize=(74717, 1, 70, 121), meta=np.ndarray>
#     EWCS              (TIME, DEPTH, LATITUDE, LONGITUDE) float64 5GB dask.array<chunksize=(74717, 1, 70, 121), meta=np.ndarray>
#     NSCS              (TIME, DEPTH, LATITUDE, LONGITUDE) float64 5GB dask.array<chunksize=(74717, 1, 70, 121), meta=np.ndarray>
#     CCOV              (TIME, DEPTH, LATITUDE, LONGITUDE) float64 5GB dask.array<chunksize=(74717, 1, 70, 121), meta=np.ndarray>
#     POSITION_QC       (TIME, DEPTH, LATITUDE, LONGITUDE) float32 3GB dask.array<chunksize=(74717, 1, 70, 121), meta=np.ndarray>
# Attributes: (12/83)
#     site_code:                       HFR-TirLig
#     platform_code:                   HFR-TirLig-Total
#     data_mode:                       R
#     doa_estimation_method:           LIGW: Direction Finding, MONT: Direction...
#     calibration_type:                LIGW: APM, MONT: APM, PCOR: APM, PFIN: A...
#     last_calibration_date:           LIGW: 2018-12-06T00:00:00Z, MONT: 2016-0...
#     ...                              ...
#     doi:
#     software_name:                   EU_HFR_NODE_NRTprocessor
#     software_version:                v3
#     references:                      Recommendation Report 2 on improved comm...
#     DODS.strlen:                     146
#     DODS.dimName:                    STRING146

# %% [markdown]
# ### 3.3. Select the variable to be inspected<a id="section_3_3"></a>

# %% [markdown]
# Let's select the variable you want to inspect. Please run the `next cell`:

# %%
# Set the variable to be inspected
var = 'EWCT'

# Extract the DataArray for the selected variable
da = ds[var]
da
# Out:
# <xarray.DataArray 'EWCT' (TIME: 74717, DEPTH: 1, LATITUDE: 70, LONGITUDE: 121)> Size: 5GB
# dask.array<open_dataset-EWCT, shape=(74717, 1, 70, 121), dtype=float64, chunksize=(74717, 1, 70, 121), chunktype=numpy.ndarray>
# Coordinates:
#   * DEPTH      (DEPTH) float32 4B 0.0
#   * LATITUDE   (LATITUDE) float32 280B 43.25 43.27 43.29 ... 44.46 44.48 44.5
#   * LONGITUDE  (LONGITUDE) float32 484B 7.507 7.532 7.557 ... 10.44 10.47 10.49
#   * TIME       (TIME) datetime64[ns] 598kB 2016-08-04T08:00:00 ... 2025-05-30...
# Attributes:
#     valid_min:            -10000
#     valid_max:            10000
#     standard_name:        surface_eastward_sea_water_velocity
#     long_name:            Surface eastward sea water velocity
#     units:                m s-1
#     sdn_parameter_name:   Eastward velocity of water current in the water body
#     sdn_parameter_urn:    SDN:P01::LCEWZZ01
#     sdn_uom_name:         Metres per second
#     sdn_uom_urn:          SDN:P06::UVAA
#     ancillary_variables:  QCflag VART_QC CSPD_QC DDNS_QC GDOP_QC

# %% [markdown]
# Use the CF conventions to identify the coordinate variables for longitude, latitude and time. Please run the `next cell`:

# %%
x = da.cf['longitude']
y = da.cf['latitude']
t = da.cf['time']
print(x.name, y.name, t.name)
# Out:
# LONGITUDE LATITUDE TIME

# %% [markdown]
# ### 3.4. Inspect the entire spatial domain for a variable at a specific time step<a id="section_3_4"></a>

# %% [markdown]
# Select the time step you want to investigate (please use the format ***YYYY-MM-DD hh:mm***). Please run the `next cell`:

# %%
timeStep = '2022-08-01 10:00'

# %% [markdown]
# Load the entire spatial domain for the selected variable at the specified time step. This operation could take a while because it reads the whole aggregated dataset stored on the EU HFR NODE THREDDS Data Server. Please run the `next cell`:

# %%
# %time
da2d = da.cf.sel(T=timeStep, method='nearest').load()
# Out:
# CPU times: user 3 μs, sys: 0 ns, total: 3 μs
# Wall time: 7.39 μs

# %% [markdown]
# Now let's plot the variable content on the entire spatial domain for the selected time step.
#
# We use the `holoviz` package to create the plot: it allows you to **interactively explore the plot**.
# By ***hovering*** on it you can display the variable value and the coordinates of the points.
# By enabling the ***zoom*** feature (icon of the square with the lens on the right of the colorbar) you can ***shift-drag*** the cursor and select an area to zoom in. You can restore the full view by clicking on the ***reset*** button (two circular arrows).
#
# Don't forget to **set the colorbar range** more suitable for the variable you want to insect by modifying the tuple assigned to ***clim***. Please run the `next cells`:

# %%
# Set the colorbar range
clim = (-1, 1)      # MODIFY THE RANGE ACCORDING TO THE VARIABLE CONTENT

# %%
da2d.hvplot(x=x.name, y=y.name, rasterize=True, geo=True, tiles='OSM', cmap='viridis', clim=clim, title= var + ' variable from ' + networkID + '-Total on ' + timeStep)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'17bbb420-80ec-4a78-a1f0-60ee848735f0': {'version…

# %% [markdown]
# ### 3.5. Inspect the time series for a variable at a specific location for a specified time range<a id="section_3_5"></a>

# %% [markdown]
# Identify the point for which the time series will be created by setting its longitude and latitude coordinates. Please run the `next cell`:

# %%
# Set the point coordinates
lon, lat = 9.8076, 43.9639           # MODIFY THE CCORDINATES FOR CHOOSING THE POINT YOU WANT TO INSPECT

# %% [markdown]
# Now set the time range for which you want the time series to be created (please use the format ***YYYY-MM-DD hh:mm***). Please run the `next cell`:

# %%
# Set the start and end time steps for selecting the time range
tStart = '2020-03-01'
tEnd = '2022-10-31'

# %% [markdown]
# Before to load the data, let's see what we are selecting. Please run the `next cell`:

# %%
da.cf.sel(X=lon, Y=lat, method="nearest").cf.sel(T=slice(tStart, tEnd))
# Out:
# <xarray.DataArray 'EWCT' (TIME: 22953, DEPTH: 1)> Size: 184kB
# dask.array<getitem, shape=(22953, 1), dtype=float64, chunksize=(22953, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * DEPTH      (DEPTH) float32 4B 0.0
#     LATITUDE   float32 4B 43.96
#     LONGITUDE  float32 4B 9.796
#   * TIME       (TIME) datetime64[ns] 184kB 2020-03-01 ... 2022-10-31T23:00:00
# Attributes:
#     valid_min:            -10000
#     valid_max:            10000
#     standard_name:        surface_eastward_sea_water_velocity
#     long_name:            Surface eastward sea water velocity
#     units:                m s-1
#     sdn_parameter_name:   Eastward velocity of water current in the water body
#     sdn_parameter_urn:    SDN:P01::LCEWZZ01
#     sdn_uom_name:         Metres per second
#     sdn_uom_urn:          SDN:P06::UVAA
#     ancillary_variables:  QCflag VART_QC CSPD_QC DDNS_QC GDOP_QC

# %% [markdown]
# Load the time series for the selected variable at the specified location and for the specified time range. This operation could take a while because it reads the whole aggregated dataset stored on the EU HFR NODE THREDDS Data Server. Please run the `next cell`:

# %%
# %time
da1d = da.cf.sel(X=lon, Y=lat, method="nearest").cf.sel(T=slice(tStart, tEnd)).load()
# Out:
# CPU times: user 4 μs, sys: 1e+03 ns, total: 5 μs
# Wall time: 10.7 μs

# %% [markdown]
# Now let's plot the time series of the selected variable for the specified location and time range.
#
# We use the `holoviz` package to create the plot: it allows you to **interactively explore the plot**.
# By ***hovering*** on it you can display the variable value and the time step of the points.
# By enabling the ***zoom*** feature (icon of the square with the lens on the right of the colorbar) you can ***shift-drag*** the cursor and select an area to zoom in. You can restore the full view by clicking on the ***reset*** button (two circular arrows).
#
# Please run the `next cells`:

# %%
da1d.hvplot(x=t.name, grid=True, title= 'Time series of variable ' + var + ' from ' + networkID + '-Total at location [' + str(lon) + ', ' + str(lat) + ']')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/core/dimension.py:1275, in Dimensioned._repr_mimebundle_(self, include, exclude)
#    1268 def _repr_mimebundle_(self, include=None, exclude=None):
#    1269     """
#    1270     Resolves the class hierarchy for the class rendering the
#    1271     object using any display hooks registered on Store.display
#    1272     hooks.  The output of all registered display_hooks is then
#    1273     combined and returned.
#    1274     """
# -> 1275     return Store.render(self)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/core/options.py:1423, in Store.render(cls, obj)
#    1421 data, metadata = {}, {}
#    1422 for hook in hooks:
# -> 1423     ret = hook(obj)
#    1424     if ret is None:
#    1425         continue
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:287, in pprint_display(obj)
#     285 if not ip.display_formatter.formatters['text/plain'].pprint:
#     286     return None
# --> 287 return display(obj, raw_output=True)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:261, in display(obj, raw_output, **kwargs)
#     259 elif isinstance(obj, (HoloMap, DynamicMap)):
#     260     with option_state(obj):
# --> 261         output = map_display(obj)
#     262 elif isinstance(obj, Plot):
#     263     output = render(obj)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:149, in display_hook.<locals>.wrapped(element)
#     147 try:
#     148     max_frames = OutputSettings.options['max_frames']
# --> 149     mimebundle = fn(element, max_frames=max_frames)
#     150     if mimebundle is None:
#     151         return {}, {}
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:209, in map_display(vmap, max_frames)
#     206     max_frame_warning(max_frames)
#     207     return None
# --> 209 return render(vmap)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:76, in render(obj, **kwargs)
#      73 if renderer.fig == 'pdf':
#      74     renderer = renderer.instance(fig='png')
# ---> 76 return renderer.components(obj, **kwargs)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/plotting/renderer.py:397, in Renderer.components(self, obj, fmt, comm, **kwargs)
#     395 if embed or config.comms == 'default':
#     396     return self._render_panel(plot, embed, comm)
# --> 397 return self._render_ipywidget(plot)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/plotting/renderer.py:419, in Renderer._render_ipywidget(self, plot)
#     417 def _render_ipywidget(self, plot):
#     418     # Handle rendering object as ipywidget
# --> 419     widget = ipywidget(plot, combine_events=True)
#     420     if hasattr(widget, '_repr_mimebundle_'):
#     421         return widget._repr_mimebundle_(), {}
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/panel/io/notebook.py:563, in ipywidget(obj, doc, **kwargs)
#     561 doc = doc if doc else Document()
#     562 model = panel(obj, **kwargs).get_root(doc=doc)
# --> 563 widget = BokehModel(model, combine_events=True)
#     564 if hasattr(widget, '_view_count'):
#     565     widget._view_count = 0
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/jupyter_bokeh/widgets.py:85, in BokehModel.__init__(self, model, **kwargs)
#      83 def __init__(self, model: LayoutDOM, **kwargs: Any) -> None:
#      84     assert isinstance(model, LayoutDOM)
# ---> 85     self.update_from_model(model)
#      86     super(BokehModel, self).__init__(**kwargs)
#      87     self.on_msg(self._sync_model)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/jupyter_bokeh/widgets.py:109, in BokehModel.update_from_model(self, model)
#     107 def update_from_model(self, model: Model) -> None:
#     108     self._model = model
# --> 109     self.render_bundle = self._model_to_traits(model)
#     110     self._document.on_change_dispatch_to(self)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/jupyter_bokeh/widgets.py:98, in BokehModel._model_to_traits(cls, model)
#      96 if model.document is None:
#      97     document = Document()
# ---> 98     document.add_root(model)
#      99 (docs_json, [render_item]) = standalone_docs_json_and_render_items([model], suppress_callback_warning=True)
#     100 render_bundle = RenderBundle(
#     101     docs_json=docs_json,
#     102     render_items=[render_item.to_json()],
#     103     div=div_for_render_item(render_item),
#     104 )
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/document/document.py:321, in Document.add_root(self, model, setter)
#     318 if model in self._roots:
#     319     return
# --> 321 with self.models.freeze():
#     322     self._roots.append(model)
#     324 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/document/models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/document/models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/document/models.py:235, in DocumentModelManager.recompute(self)
#     232     md._detach_document()
#     234 for ma in to_attach:
# --> 235     ma._attach_document(document)
#     236     self._new_models.add(ma)
#     238 self._models = recomputed
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/model/model.py:596, in Model._attach_document(self, doc)
#     593     return
#     595 if self.document is not None:
# --> 596     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
#     598 doc.theme.apply_to_model(self)
#     599 self.document = doc
#
# RuntimeError: Models must be owned by only a single document, ImportedStyleSheet(id='b071150c-edc8-4b63-bbc7-2ab2d7737639', ...) is already in a doc
# :DynamicMap   [DEPTH]
#    :Curve   [TIME]   (Surface eastward sea water velocity)

# %% [markdown]
# ### 3.6. Compute the average of a variable over the entire spatial domain for a specified time period<a id="section_3_6"></a>

# %% [markdown]
# Set the time period for which you want the average to be computed (please use the format ***YYYY-MM-DD hh:mm***). Please run the `next cell`:

# %%
# Set the start and end time steps for selecting the time range
tStart = '2020-03-01'
tEnd = '2022-10-31'

# %% [markdown]
# Now evaluate the average over the selected time period. This operation could take a while because it reads the whole aggregated dataset stored on the EU HFR NODE THREDDS Data Server. Please run the `next cell`:

# %%
# %time
da_avg = da.cf.sel(T=slice(tStart, tEnd)).mean(dim=t.name).compute()
# Out:
# CPU times: user 5 μs, sys: 1e+03 ns, total: 6 μs
# Wall time: 9.78 μs

# %% [markdown]
# Now let's plot the variable average on the entire spatial domain for the selected time period.
#
# We use the `holoviz` package to create the plot: it allows you to **interactively explore the plot**.
# By ***hovering*** on it you can display the variable value and the coordinates of the points.
# By enabling the ***zoom*** feature (icon of the square with the lens on the right of the colorbar) you can ***shift-drag*** the cursor and select an area to zoom in. You can restore the full view by clicking on the ***reset*** button (two circular arrows).
#
# Don't forget to **set the colorbar range** more suitable for the variable you want to insect by modifying the tuple assigned to ***clim***. Please run the `next cells`:

# %%
# Set the colorbar range
clim = (-1, 1)      # MODIFY THE RANGE ACCORDING TO THE VARIABLE CONTENT

# %%
da_avg.hvplot(x=x.name, y=y.name, rasterize=True, geo=True, tiles='OSM', cmap='viridis', clim=clim, title= 'Average of variable ' + var + ' from ' + networkID + '-Total from ' + tStart + ' to ' + tEnd)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/core/dimension.py:1275, in Dimensioned._repr_mimebundle_(self, include, exclude)
#    1268 def _repr_mimebundle_(self, include=None, exclude=None):
#    1269     """
#    1270     Resolves the class hierarchy for the class rendering the
#    1271     object using any display hooks registered on Store.display
#    1272     hooks.  The output of all registered display_hooks is then
#    1273     combined and returned.
#    1274     """
# -> 1275     return Store.render(self)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/core/options.py:1423, in Store.render(cls, obj)
#    1421 data, metadata = {}, {}
#    1422 for hook in hooks:
# -> 1423     ret = hook(obj)
#    1424     if ret is None:
#    1425         continue
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:287, in pprint_display(obj)
#     285 if not ip.display_formatter.formatters['text/plain'].pprint:
#     286     return None
# --> 287 return display(obj, raw_output=True)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:261, in display(obj, raw_output, **kwargs)
#     259 elif isinstance(obj, (HoloMap, DynamicMap)):
#     260     with option_state(obj):
# --> 261         output = map_display(obj)
#     262 elif isinstance(obj, Plot):
#     263     output = render(obj)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:149, in display_hook.<locals>.wrapped(element)
#     147 try:
#     148     max_frames = OutputSettings.options['max_frames']
# --> 149     mimebundle = fn(element, max_frames=max_frames)
#     150     if mimebundle is None:
#     151         return {}, {}
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:209, in map_display(vmap, max_frames)
#     206     max_frame_warning(max_frames)
#     207     return None
# --> 209 return render(vmap)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:76, in render(obj, **kwargs)
#      73 if renderer.fig == 'pdf':
#      74     renderer = renderer.instance(fig='png')
# ---> 76 return renderer.components(obj, **kwargs)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/plotting/renderer.py:397, in Renderer.components(self, obj, fmt, comm, **kwargs)
#     395 if embed or config.comms == 'default':
#     396     return self._render_panel(plot, embed, comm)
# --> 397 return self._render_ipywidget(plot)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/holoviews/plotting/renderer.py:419, in Renderer._render_ipywidget(self, plot)
#     417 def _render_ipywidget(self, plot):
#     418     # Handle rendering object as ipywidget
# --> 419     widget = ipywidget(plot, combine_events=True)
#     420     if hasattr(widget, '_repr_mimebundle_'):
#     421         return widget._repr_mimebundle_(), {}
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/panel/io/notebook.py:563, in ipywidget(obj, doc, **kwargs)
#     561 doc = doc if doc else Document()
#     562 model = panel(obj, **kwargs).get_root(doc=doc)
# --> 563 widget = BokehModel(model, combine_events=True)
#     564 if hasattr(widget, '_view_count'):
#     565     widget._view_count = 0
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/jupyter_bokeh/widgets.py:85, in BokehModel.__init__(self, model, **kwargs)
#      83 def __init__(self, model: LayoutDOM, **kwargs: Any) -> None:
#      84     assert isinstance(model, LayoutDOM)
# ---> 85     self.update_from_model(model)
#      86     super(BokehModel, self).__init__(**kwargs)
#      87     self.on_msg(self._sync_model)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/jupyter_bokeh/widgets.py:109, in BokehModel.update_from_model(self, model)
#     107 def update_from_model(self, model: Model) -> None:
#     108     self._model = model
# --> 109     self.render_bundle = self._model_to_traits(model)
#     110     self._document.on_change_dispatch_to(self)
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/jupyter_bokeh/widgets.py:98, in BokehModel._model_to_traits(cls, model)
#      96 if model.document is None:
#      97     document = Document()
# ---> 98     document.add_root(model)
#      99 (docs_json, [render_item]) = standalone_docs_json_and_render_items([model], suppress_callback_warning=True)
#     100 render_bundle = RenderBundle(
#     101     docs_json=docs_json,
#     102     render_items=[render_item.to_json()],
#     103     div=div_for_render_item(render_item),
#     104 )
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/document/document.py:321, in Document.add_root(self, model, setter)
#     318 if model in self._roots:
#     319     return
# --> 321 with self.models.freeze():
#     322     self._roots.append(model)
#     324 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/document/models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/document/models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/document/models.py:235, in DocumentModelManager.recompute(self)
#     232     md._detach_document()
#     234 for ma in to_attach:
# --> 235     ma._attach_document(document)
#     236     self._new_models.add(ma)
#     238 self._models = recomputed
#
# File ~/miniforge3/envs/pangeo/lib/python3.11/site-packages/bokeh/model/model.py:596, in Model._attach_document(self, doc)
#     593     return
#     595 if self.document is not None:
# --> 596     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
#     598 doc.theme.apply_to_model(self)
#     599 self.document = doc
#
# RuntimeError: Models must be owned by only a single document, ImportedStyleSheet(id='abd1b463-6ebc-4425-b880-269f7c53c27f', ...) is already in a doc
# :DynamicMap   [DEPTH]
#    :Overlay
#       .WMTS.I  :WMTS   [Longitude,Latitude]
#       .Image.I :Image   [LONGITUDE,LATITUDE]   (EWCT)

# %% [markdown]
# ## 4. Inspect radial current field datasets<a class="anchor" id="chapter4"></a>
# [Go back to the "Table of Contents"](#Table-of-Contents)

# %% [markdown]
# In this section we'll inspect the radial velocity field data produced by your HFR network. In particular, we'll check: **(i) the entire spatial domain for a variable at a specific time step, (ii) the time series of a variable at a specific location for a specified time range, (iii) the average of a variable over the entire spatial domain for a specified time period**.

# %% [markdown]
# ### 4.1. Open dataset from the EU HFR NODE THREDDS Data Server<a id="section_4_1"></a>

# %% [markdown]
# Now we open the radial velocity datasets of each radial station of your HFR network This operation could take a while because it reads the whole aggregated dataset stored on the EU HFR NODE THREDDS Data Server. Please run the `next cell`:

# %%
# Create an empty list for containing the radial datasets
Rds = []

# Loop through radial sites
for Rindex, site in stationData.iterrows():
    # Get the TDS URL of the dataset
    OpenDAPdataUrl = site['SDC_OpenDAP_data_url']

    # Read aggregated total dataset from THREDDS catalog via OpenDAP
    Rds.append(xr.open_dataset(OpenDAPdataUrl, decode_times=True, chunks={}))

# %% [markdown]
# ### 4.2. Select the variable to be inspected<a id="section_4_2"></a>

# %% [markdown]
# Let's select the variable you want to inspect. Please run the `next cell`:

# %%
# Set the variable to be inspected
var = 'EWCT'

# Create an empty dictionary for containing the DataArrays of the selected variable for each radial datasets
radDA = {}

# Loop through radial sites
for rad in Rds:
    # Extract the DataArrays for the selected variable
    radDA[rad.attrs['platform_code']] = rad[var]

# %% [markdown]
# ### 4.3. Inspect the entire spatial domain for a variable at a specific time step<a id="section_4_3"></a>

# %% [markdown]
# Select the time step you want to investigate (please use the format ***YYYY-MM-DD hh:mm***). Please run the `next cell`:

# %%
timeStep = '2022-08-01 10:00'

# %% [markdown]
# Load the entire spatial domain for the selected variable at the specified time step for each radial site. This operation could take a while because it reads the whole aggregated dataset stored on the EU HFR NODE THREDDS Data Server. Please run the `next cell`:

# %%
# %time

# Create an empty dictionary for containing the DataArrays of the selected variable for each radial datasets
radDAts = {}          

# Loop through radial sites
for key,val in radDA.items():
    radDAts[key] = val.cf.sel(T=timeStep, method='nearest').load()
# Out:
# CPU times: user 5 μs, sys: 1e+03 ns, total: 6 μs
# Wall time: 10.7 μs

# %% [markdown]
# Now let's plot the variable content on the entire spatial domain for the selected time step for each radial site.
#
# We use the `holoviz` package to create the plot: it allows you to **interactively explore the plot**.
# By ***hovering*** on it you can display the variable value and the coordinates of the points.
# By enabling the ***zoom*** feature (icon of the square with the lens on the right of the colorbar) you can ***shift-drag*** the cursor and select an area to zoom in. You can restore the full view by clicking on the ***reset*** button (two circular arrows).
#
# Don't forget to **set the colorbar range** more suitable for the variable you want to insect by modifying the tuple assigned to ***clim***. Please run the `next cells`:

# %%
# Set the colorbar range
clim = (-1, 1)      # MODIFY THE RANGE ACCORDING TO THE VARIABLE CONTENT

# %%
# Enable Panel extension
pn.extension()

# Create the plots
plots = []
for key,val in radDAts.items():
        x = val.cf['longitude']
        y = val.cf['latitude']
        t = val.cf['time']
        plot = val.hvplot.quadmesh(x=x.name, y=y.name, rasterize=True, geo=True, tiles='OSM', cmap='viridis', clim=clim, title= var + ' variable from ' + key + ' on ' + timeStep)
        plots.append(plot)

# Calculate number of rows and columns for a balanced grid
n_plots = len(plots)
ncols = math.ceil(math.sqrt(n_plots))
nrows = math.ceil(n_plots / ncols)

# Arrange the plots in a grid layout
grid = pn.GridBox(*plots, ncols=ncols)

# Serve or display the layout
grid.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='064807a3-586d-40a6-810e-c870f185a543'>
#   <div id="f7b51d68-181c-4c8d-9f31-046f072aff41" data-root-id="064807a3-586d-40a6-810e-c870f185a543" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"89d8a72a-e370-4aff-a883-3500ccfc7013":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"064807a3-586d-40a6-810e-c870f185a543"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"df211999-558a-40a1-ac2b-1e248d78a851","attributes":{"plot_id":"064807a3-586d-40a6-810e-c870f185a543","comm_id":"51d0ad25767942bda041f777b74b0f4b","client_comm_id":"ffce8f46c2b943eab62118f6337553aa"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"89d8a72a-e370-4aff-a883-3500ccfc7013","roots":{"064807a3-586d-40a6-810e-c870f185a543":"f7b51d68-181c-4c8d-9f31-046f072aff41"},"root_ids":["064807a3-586d-40a6-810e-c870f185a543"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'2334060e-8406-48f4-a1c2-1bb660fa9ee3': {'version…

# %% [markdown]
# ### 4.4. Inspect the time series for a variable at a specific location for a specified time range<a id="section_4_4"></a>

# %% [markdown]
# Identify the point for which the time series will be created by setting its longitude and latitude coordinates. Please run the `next cell`:

# %%
# Set the point coordinates
lon, lat = 9.8076, 43.9639           # MODIFY THE CCORDINATES FOR CHOOSING THE POINT YOU WANT TO INSPECT

# %% [markdown]
# Now set the time range for which you want the time series to be created (please use the format ***YYYY-MM-DD hh:mm***). Please run the `next cell`:

# %%
# Set the start and end time steps for selecting the time range
tStart = '2022-03-01'
tEnd = '2022-10-31'

# %% [markdown]
# Load the time series for the selected variable at the specified location and for the specified time range for each radial site. This operation could take a while because it reads the whole aggregated dataset stored on the EU HFR NODE THREDDS Data Server. Please run the `next cell`:

# %%
# %time

# Create an empty dictionary for containing the DataArrays of the selected variable for each radial datasets
radDAltr = {}          

# Loop through radial sites
for key,val in radDA.items():
    tmpDA = val.cf.sel(X=lon, Y=lat, Z=0, method="nearest").cf.sel(T=slice(tStart, tEnd)).load()
    # Keep only non-empty time series
    if not np.isnan(tmpDA.values).all():
        radDAltr[key] = tmpDA
# Out:
# CPU times: user 4 μs, sys: 1e+03 ns, total: 5 μs
# Wall time: 9.3 μs

# %% [markdown]
# Now let's plot the time series of the selected variable for the specified location and time range for each radial site. **Only the non-empty time series will be plotted** (a time series could be empty either because no data is present in that location for that time range or the location is outside the radial site coverage).
#
# We use the `holoviz` package to create the plot: it allows you to **interactively explore the plot**.
# By ***hovering*** on it you can display the variable value and the time step of the points.
# By enabling the ***zoom*** feature (icon of the square with the lens on the right of the colorbar) you can ***shift-drag*** the cursor and select an area to zoom in. You can restore the full view by clicking on the ***reset*** button (two circular arrows).
#
# Please run the `next cells`:

# %%
# Enable Panel extension
pn.extension()

# Create the plots
plots = []
for key,val in radDAltr.items():
        x = val.cf['longitude']
        y = val.cf['latitude']
        t = val.cf['time']
        plot = val.hvplot(x=t.name, grid=True, title= 'Time series of variable ' + var + ' variable from ' + key + ' at location [' + str(lon) + ', ' + str(lat) + ']')
        plots.append(plot)

# Calculate number of rows and columns for a balanced grid
n_plots = len(plots)
ncols = math.ceil(math.sqrt(n_plots))
nrows = math.ceil(n_plots / ncols)

# Arrange the plots in a grid layout
grid = pn.GridBox(*plots, ncols=ncols)

# Serve or display the layout
grid.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='5b91aa8a-6ace-4d4d-9d2a-aed377ee68de'>
#   <div id="ab14865f-7401-4d29-8311-7c90f0566f83" data-root-id="5b91aa8a-6ace-4d4d-9d2a-aed377ee68de" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"26705ee6-0bf0-47f2-bf5e-b49a346f9802":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"5b91aa8a-6ace-4d4d-9d2a-aed377ee68de"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"b8b0f304-a347-4f66-9c20-9a1d97f8455f","attributes":{"plot_id":"5b91aa8a-6ace-4d4d-9d2a-aed377ee68de","comm_id":"6d41f5016b6e410e9aa39a51be09c341","client_comm_id":"1738a28998f0453b94be75e9886839ca"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"26705ee6-0bf0-47f2-bf5e-b49a346f9802","roots":{"5b91aa8a-6ace-4d4d-9d2a-aed377ee68de":"ab14865f-7401-4d29-8311-7c90f0566f83"},"root_ids":["5b91aa8a-6ace-4d4d-9d2a-aed377ee68de"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'92515198-d145-4188-94fc-3ba903c326e6': {'version…

# %% [markdown]
# ### 4.5. Compute the average of a variable over the entire spatial domain for a specified time period<a id="section_4_5"></a>

# %% [markdown]
# Set the time period for which you want the average to be computed (please use the format ***YYYY-MM-DD hh:mm***). Please run the `next cell`:

# %%
# Set the start and end time steps for selecting the time range
tStart = '2020-03-01'
tEnd = '2022-10-31'

# %% [markdown]
# Now evaluate the average over the selected time period for each radial site. This operation could take a while because it reads the whole aggregated dataset stored on the EU HFR NODE THREDDS Data Server. Please run the `next cell`:

# %%
# %time

# Create an empty dictionary for containing the DataArrays of the average of the selected variable for each radial datasets
radDAavg = {}          

# Loop through radial sites
for key,val in radDA.items():
    radDAavg[key] = val.cf.sel(T=slice(tStart, tEnd)).mean(dim=t.name).compute()
# Out:
# CPU times: user 4 μs, sys: 1e+03 ns, total: 5 μs
# Wall time: 9.54 μs

# %% [markdown]
# Now let's plot the variable average on the entire spatial domain for the selected time period for each radial site.
#
# We use the `holoviz` package to create the plot: it allows you to **interactively explore the plot**.
# By ***hovering*** on it you can display the variable value and the coordinates of the points.
# By enabling the ***zoom*** feature (icon of the square with the lens on the right of the colorbar) you can ***shift-drag*** the cursor and select an area to zoom in. You can restore the full view by clicking on the ***reset*** button (two circular arrows).
#
# Don't forget to **set the colorbar range** more suitable for the variable you want to insect by modifying the tuple assigned to ***clim***. Please run the `next cells`:

# %%
# Set the colorbar range
clim = (-1, 1)      # MODIFY THE RANGE ACCORDING TO THE VARIABLE CONTENT

# %%
# Enable Panel extension
pn.extension()

# Create the plots
plots = []
for key,val in radDAavg.items():
        x = val.cf['longitude']
        y = val.cf['latitude']
        plot = val.hvplot.quadmesh(x=x.name, y=y.name, rasterize=True, geo=True, tiles='OSM', cmap='viridis', clim=clim, title= 'Average of variable ' + var + ' from ' + key + ' from ' + tStart + ' to ' + tEnd)
        plots.append(plot)

# Calculate number of rows and columns for a balanced grid
n_plots = len(plots)
ncols = math.ceil(math.sqrt(n_plots))
nrows = math.ceil(n_plots / ncols)

# Arrange the plots in a grid layout
grid = pn.GridBox(*plots, ncols=ncols)

# Serve or display the layout
grid.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='17d94967-727a-46e7-9a42-cda9e286b352'>
#   <div id="c26e3440-8f42-4467-a2e9-373ce61297eb" data-root-id="17d94967-727a-46e7-9a42-cda9e286b352" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"37b48fd4-5203-4502-b277-623e5ff7d64a":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"17d94967-727a-46e7-9a42-cda9e286b352"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"969e5c49-d948-49e5-9e44-e0bb2bd35490","attributes":{"plot_id":"17d94967-727a-46e7-9a42-cda9e286b352","comm_id":"ec19aba7ee2549c3bde893bb14d9fd70","client_comm_id":"f1f26255479e4f048532ba9f3b4ce0b4"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"37b48fd4-5203-4502-b277-623e5ff7d64a","roots":{"17d94967-727a-46e7-9a42-cda9e286b352":"c26e3440-8f42-4467-a2e9-373ce61297eb"},"root_ids":["17d94967-727a-46e7-9a42-cda9e286b352"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'3149905f-983e-4a96-9c06-3790cba9424d': {'version…

# %% [markdown]
# ### 4.6. Stop the cluster<a id="section_4_6"></a>

# %%
client.shutdown()
